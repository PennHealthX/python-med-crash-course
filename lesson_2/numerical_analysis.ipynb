# %% [markdown]
# # Introduction to Numerical Analysis with Python
#
# Welcome to numerical analysis! In health research and data science, you'll often work with large datasets, perform statistical analyses, and create visualizations. Python has three essential libraries that make this work incredibly powerful:
#
# **NumPy (Numerical Python)**
# - Fast mathematical operations on large arrays and matrices
# - Think: efficiently processing thousands of patient measurements at once
# - Used for: numerical computing, linear algebra, statistical calculations
#
# **Pandas (Panel Data)**
# - Works with structured data (like spreadsheets and databases)
# - Think: organizing and analyzing patient records, clinical trial data
# - Used for: data cleaning, filtering, grouping, and analysis
#
# **Matplotlib**
# - Creates publication-quality graphs and visualizations
# - Think: plotting trends, distributions, and research findings
# - Used for: charts, histograms, scatter plots, and more
#
# ## Why These Matter in Health Research
#
# Imagine you have data from 10,000 patients. With these tools, you can:
# - Calculate statistics across all patients in milliseconds (NumPy)
# - Filter patients by age, condition, or treatment group (Pandas)
# - Visualize treatment outcomes and identify trends (Matplotlib)
#
# These libraries work together seamlessly and are the foundation of data science in Python. Let's learn how to use them!
#
# ---

# %% [markdown]
# ## Using External Code: Import Statements
#
# Python comes with many built-in tools (called **modules** or **libraries**) that add extra functionality. Instead of writing everything from scratch, you can **import** these tools and use them!
#
# ### Why Use Imports?
#
# Think of modules like apps on your phone. Your phone has basic features, but you download apps to do specific things (social media, games, navigation). Similarly, Python has basic features, but you import modules to do specialized tasks like:
#
# - Math calculations (beyond basic +, -, *, /)
# - Working with dates and times
# - Reading/writing files
# - Analyzing data
# - Making graphs
# - And much more!
#
# **NumPy**, **Pandas**, and **Matplotlib** are external libraries that we will need to import.
#
# ### Basic Import

# %%
# Import the math module
import math

# Now we can use functions from the math module
print(math.sqrt(16))        # Square root of 16 = 4.0
print(math.pi)              # The value of pi
print(math.pow(2, 3))       # 2 to the power of 3 = 8.0
print(math.floor(4.7))      # Round down = 4
print(math.ceil(4.3))       # Round up = 5
# Out:
# 4.0
# 3.141592653589793
# 8.0
# 4
# 5

# %% [markdown]
# Notice the pattern: `modulename.function()`. After importing, you use the module name followed by a dot, then the function name.
#
# ### Importing Specific Functions
#
# If you only need specific functions, you can import just those:

# %%
# Import only sqrt and pi from math
from math import sqrt, pi

# Now you can use them without "math."
print(sqrt(25))    # 5.0
print(pi)          # 3.141592...
# Out:
# 5.0
# 3.141592653589793

# %% [markdown]
# ### Using Aliases (Nicknames)
#
# Sometimes module names are long. You can give them shorter nicknames:

# %%
# Import with a nickname (very common in data science!)
import math as m

print(m.sqrt(64))  # 8.0
# Out:
# 8.0

# %% [markdown]
# ### Common Built-in Modules
#
# Here are some useful modules that come with Python (no installation needed):
#
# #### 1. random - Generate random numbers

# %%
import random

# Random integer between 1 and 10
print(random.randint(1, 10))

# Random decimal between 0 and 1
print(random.random())

# Choose a random item from a list
colors = ["red", "blue", "green", "yellow"]
print(random.choice(colors))
# Out:
# 10
# 0.44402550109737116
# red

# %% [markdown]
# #### 2. datetime - Work with dates and times

# %%
from datetime import datetime

# Get current date and time
now = datetime.now()
print("Current date and time:", now)

# Get just the date
print("Today's date:", now.date())

# Get just the time
print("Current time:", now.time())
# Out:
# Current date and time: 2026-01-25 19:29:27.014815
# Today's date: 2026-01-25
# Current time: 19:29:27.014815

# %% [markdown]
# #### 3. statistics - Basic statistical calculations

# %%
import statistics

data = [10, 20, 30, 40, 50]

print("Mean:", statistics.mean(data))      # Average
print("Median:", statistics.median(data))  # Middle value
print("Stdev:", statistics.stdev(data))    # Standard deviation
# Out:
# Mean: 30
# Median: 30
# Stdev: 15.811388300841896

# %% [markdown]
# ## Numpy

# %% [markdown]
# NumPy is a python library used for efficient computations. We often use NumPy to manipulate data stored within larger data tables. NumPy's efficiency relies on storing data that is all of the same type. Here, we will explore NumPy functions by applying them to 1D arrays. In the Pandas section, we will explore more advanced and practical uses of NumPy.

# %%
import numpy as np

# Create arrays with medical information
age = np.array([32, 15, 23, 66])
heart_rate = np.array([66, 120, 176, 77])
systolic_bp = np.array([140, 110, 80, 97])

# Use numpy functions to create statistics
average_age = np.mean(age)
average_hr = np.mean(heart_rate)
average_sbp = np.mean(systolic_bp)

print(f"The average age, heart rate, and systolic BP are {average_age}, {average_hr}, and {average_sbp}.")
# Out:
# The average age, heart rate, and systolic BP are 34.0, 109.75, and 106.75.

# %% [markdown]
# ## Pandas

# %% [markdown]
# Pandas is a Python package commonly used to manipulate tabular data.
#
# **Series:** This is a single column of data.
#
# **DataFrame:** We can create a multi-dimensional dataframe or upload data from a csv file into the format of a Pandas DataFrame in order to use various functions on that data. We can think of a DataFrame as a collection of Series where each column in the DataFrame is a Series.

# %% [markdown]
# ## Cornelius Still in the ED

# %% [markdown]
# In the rush to figure out Cornelius and his community's risk for ATIUED, you forgot to address what Cornelius came to the ED for -- his explosive diarrhea. Despite several attempts to leave the ED in fear of rising medical bills, Cornelius was unable to make it past the bathroom. Now, you must find the right treatment plan for Cornelius by evaluating potential treatment options. Luckily, your prolific prescribing habits have not gone unrecognized. Drugs.com has provided you with a dataset consisting of a list of drugs and their side effects.

# %%
import pandas as pd

# %%
drug_side_effects = pd.read_csv("drug_side_effects.csv")

# %%
drug_side_effects.head()
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %% [markdown]
# Overwhelmed by the dataset, you must retain only the information that might be useful.

# %%
drug_side_effects.columns
# Out:
# Index(['drug_name', 'medical_condition', 'side_effects', 'generic_name',
#        'drug_classes', 'brand_names', 'activity', 'rx_otc',
#        'pregnancy_category', 'csa', 'alcohol', 'related_drugs',
#        'medical_condition_description', 'rating', 'no_of_reviews', 'drug_link',
#        'medical_condition_url'],
#       dtype='object')

# %%
drug_side_effects_brief = drug_side_effects.drop(['related_drugs',
       'medical_condition_description', 'rating', 'no_of_reviews', 'drug_link',
       'medical_condition_url'], axis=1)

# %%
drug_side_effects_brief.head()
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %% [markdown]
# In order to find the treatment options for Cornelius, we need to find the list of medications that are used to treat diarrhea specifically.

# %%
diarrhea = drug_side_effects_brief.loc[drug_side_effects_brief["medical_condition"]=="Diarrhea", :]

# %%
diarrhea.head()
# Out:
#                      drug_name medical_condition  \
# 1361                loperamide          Diarrhea
# 1362                   Lomotil          Diarrhea
# 1363                   Imodium          Diarrhea
# 1364  atropine / diphenoxylate          Diarrhea
# 1365               Imodium A-D          Diarrhea
#
#                                            side_effects  \
# 1361  diarrhea that is watery or bloody; stomach pai...
# 1362  hives ; difficult breathing; swelling of your ...
# 1363  Along with its needed effects, a medicine may ...
# 1364  hives ; difficult breathing; swelling of your ...
# 1365  diarrhea that is watery or bloody; stomach pai...
#
#                     generic_name    drug_classes  \
# 1361                  loperamide  Antidiarrheals
# 1362  atropine and diphenoxylate  Antidiarrheals
# 1363     loperamide (oral route)  Antidiarrheals
# 1364  atropine and diphenoxylate  Antidiarrheals
# 1365                  loperamide  Antidiarrheals
#
# ...

# %%
print("There are", len(diarrhea), "medications that are used to treat diarrhea.")
# Out:
# There are 38 medications that are used to treat diarrhea.

# %%
diarrhea["drug_name"].values
# Out:
# array(['loperamide', 'Lomotil', 'Imodium', 'atropine / diphenoxylate',
#        'Imodium A-D', 'Anti-Diarrheal', 'Pepto-Bismol', 'Florastor',
#        'codeine', 'bismuth subsalicylate', 'Diamode', 'Kaopectate',
#        'rifaximin', 'Up and Up Anti-Diarrheal Solution', 'neomycin',
#        'saccharomyces boulardii lyo', 'Bismatrol', 'opium', 'Bismarex',
#        'Bismatrol Maximum Strength', 'crofelemer', 'Florastor Kids',
#        'Mytesi', 'Pedialyte', 'Peptic Relief', 'Pink Bismuth',
#        'Saccharomyces Boulardii+MOS', 'Soothe Caplets',
#        'atropine / difenoxin', 'CeraLyte',
#        'electrolyte replacement solutions', 'Enfalyte', 'Equalyte',
#        'Medi-Lyte', 'Motofen', 'Oralyte', 'Rehydralyte', 'ReVital'],
#       dtype=object)

# %%
diarrhea["activity"] = diarrhea["activity"].str.rstrip("%").astype(float)
# Out:
# /var/folders/tk/q0tyrs955dzfn0bhqlss6lxw0000gn/T/ipykernel_72697/3269611431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diarrhea["activity"] = diarrhea["activity"].str.rstrip("%").astype(float)

# %%
diarrhea.sort_values("activity", ascending=False)
# Out:
#                               drug_name medical_condition  \
# 1361                         loperamide          Diarrhea
# 1362                            Lomotil          Diarrhea
# 1363                            Imodium          Diarrhea
# 1364           atropine / diphenoxylate          Diarrhea
# 1365                        Imodium A-D          Diarrhea
# 1366                     Anti-Diarrheal          Diarrhea
# 1367                       Pepto-Bismol          Diarrhea
# 1368                          Florastor          Diarrhea
# 1369                            codeine          Diarrhea
# 1371                            Diamode          Diarrhea
# 1372                         Kaopectate          Diarrhea
# 1370              bismuth subsalicylate          Diarrhea
# 1373                          rifaximin          Diarrhea
# 1374  Up and Up Anti-Diarrheal Solution          Diarrhea
# 1375                           neomycin          Diarrhea
# ...

# %% [markdown]
# You want to know more about how effective these medications generally are in treating diarrhea.

# %%
diarrhea.groupby("drug_classes")["activity"].mean()
# Out:
# drug_classes
# Aminoglycosides                                 4.000000
# Antidiarrheals                                 17.500000
# Antidiarrheals, Probiotics                      5.333333
# Antitussives, Opioids (narcotic analgesics)     8.000000
# Minerals and electrolytes                       0.125000
# Miscellaneous antibiotics                       5.000000
# Opioids (narcotic analgesics)                   3.000000
# Probiotics                                      1.000000
# Name: activity, dtype: float64

# %% [markdown]
# Cornelius has another musical festival coming up and would only like to take a drug that does not interfere with alcohol.

# %%
diarrhea["alcohol"].value_counts()
# Out:
# alcohol
# X    12
# Name: count, dtype: int64

# %%
diarrhea.loc[diarrhea["alcohol"].isna(),["alcohol"]] = 0
# Out:
# /var/folders/tk/q0tyrs955dzfn0bhqlss6lxw0000gn/T/ipykernel_72697/1806474885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diarrhea.loc[diarrhea["alcohol"].isna(),["alcohol"]] = 0

# %%
diarrhea["alcohol"].value_counts()
# Out:
# alcohol
# 0    26
# X    12
# Name: count, dtype: int64

# %%
diarrhea_no_alc = diarrhea.loc[diarrhea["alcohol"]==0, :]

# %%
diarrhea_no_alc
# Out:
#                               drug_name medical_condition  \
# 1367                       Pepto-Bismol          Diarrhea
# 1368                          Florastor          Diarrhea
# 1370              bismuth subsalicylate          Diarrhea
# 1372                         Kaopectate          Diarrhea
# 1373                          rifaximin          Diarrhea
# 1375                           neomycin          Diarrhea
# 1376        saccharomyces boulardii lyo          Diarrhea
# 1377                          Bismatrol          Diarrhea
# 1379                           Bismarex          Diarrhea
# 1380         Bismatrol Maximum Strength          Diarrhea
# 1381                         crofelemer          Diarrhea
# 1382                     Florastor Kids          Diarrhea
# 1383                             Mytesi          Diarrhea
# 1384                          Pedialyte          Diarrhea
# 1385                      Peptic Relief          Diarrhea
# ...

# %%
diarrhea_no_alc["side_effects"].values
# Out:
# array(['hives ; difficulty breathing; swelling of your face, lips, tongue, or throat. Stop taking this medicine and call your doctor at once if you have: changes in behavior with nausea and vomiting ; hearing loss or ringing in your ears; diarrhea lasting longer than 2 days; or worsened stomach symptoms. Bismuth subsalicylate can cause you to have a black or darkened tongue. This is a harmless side effect. Common side effects include: constipation ; or dark colored stools.',
#        'hives ; difficult breathing; swelling of your face, lips, tongue, or throat. Although not all side effects are known, Florastor is thought to be likely safe for most people when used as directed for up to 15 months. Common side effects of Florastor may include: gas, bloating ; or constipation .',
# ...

# %% [markdown]
# Upon reading the side effects for each of the medications, you find that some of them can actually lead to increased diarrhea or stomach pain. Not being willing to take that risk as the other patients are starting to complain of a horrid stink coming from the bathroom, you decide to eliminate all medications that could potentially perpetuate the diarrhea.

# %%
diarrhea_no_alc["causes_diarrhea"] = diarrhea_no_alc["side_effects"].str.contains("worse")
# Out:
# /var/folders/tk/q0tyrs955dzfn0bhqlss6lxw0000gn/T/ipykernel_72697/1754681985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diarrhea_no_alc["causes_diarrhea"] = diarrhea_no_alc["side_effects"].str.contains("worse")

# %%
diarrhea_no_alc["causes_diarrhea"].value_counts()
# Out:
# causes_diarrhea
# False    15
# True     11
# Name: count, dtype: int64

# %%
diarrhea_no_alc_no_diarrhea = diarrhea_no_alc.loc[diarrhea_no_alc["causes_diarrhea"]==False, :]

# %%
diarrhea_no_alc_no_diarrhea["activity"] = diarrhea_no_alc_no_diarrhea["activity"].str.rstrip("%").astype(float)
# Out:
# /var/folders/tk/q0tyrs955dzfn0bhqlss6lxw0000gn/T/ipykernel_72697/3328368402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diarrhea_no_alc_no_diarrhea["activity"] = diarrhea_no_alc_no_diarrhea["activity"].str.rstrip("%").astype(float)

# %%
diarrhea_no_alc_no_diarrhea.sort_values("activity", ascending=False)
# Out:
#                               drug_name medical_condition  \
# 1368                          Florastor          Diarrhea
# 1373                          rifaximin          Diarrhea
# 1375                           neomycin          Diarrhea
# 1376        saccharomyces boulardii lyo          Diarrhea
# 1382                     Florastor Kids          Diarrhea
# 1384                          Pedialyte          Diarrhea
# 1387        Saccharomyces Boulardii+MOS          Diarrhea
# 1390                           CeraLyte          Diarrhea
# 1391  electrolyte replacement solutions          Diarrhea
# 1392                           Enfalyte          Diarrhea
# 1393                           Equalyte          Diarrhea
# 1394                          Medi-Lyte          Diarrhea
# 1396                            Oralyte          Diarrhea
# 1397                        Rehydralyte          Diarrhea
# 1398                            ReVital          Diarrhea
#
# ...

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Matplotlib is a library that is commonly used to create graphs. This can be used to visually present the findings that you derived from using Pandas functions.

# %%
import matplotlib.pyplot as plt

# %%
# Aggregate: count stroke cases by smoking status
diarrhea_class = diarrhea.groupby("drug_classes")["activity"].median()  

# Plot
plt.figure(figsize=(6,4))
diarrhea_class.plot(kind='bar', color='skyblue')
plt.title("Activity Level of Drug Classes for Diarrhea")
plt.ylabel("Activity Level for Drug Class")
plt.xlabel("Drug Class")
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
# Aggregate: count stroke cases by smoking status
diarrhea_class = diarrhea.groupby("drug_classes")["activity"].median().sort_values(ascending=False)

# Plot
plt.figure(figsize=(6,4))
diarrhea_class.plot(kind='bar', color='skyblue')
plt.title("Activity Level of Drug Classes for Diarrhea")
plt.ylabel("Activity Level for Drug Class")
plt.xlabel("Drug Class")
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Your Turn!

# %% [markdown]
# Thanks to your quick assessment, Cornelius was finally able to leave the ED—armed with discharge papers, a cautious diet, and a newfound respect for antidiarrheals.
#
# As the department settles back into its usual controlled chaos, your colleagues take notice. Word spreads quickly: you didn’t just treat the patient—you interrogated the data.
#
# Soon, a small crowd of fellow physicians gathers around your workstation. One question rises above the din of monitor alarms and coffee refills:
#
# “So… what does the data actually say about smoking and heart disease?”
#
# With the confidence of someone who has already conquered both colitis and CSV files, you turn back to the dataset—ready to trade explosive diarrhea for atherosclerosis.

# %%
stroke_data = pd.read_csv("stroke-kaggle.csv")

# %% [markdown]
# ### Exercise 1: For patients with heart disease, determine the fraction of people who are current smokers.

# %%
# Select for patients with heart disease
heart_disease = stroke_data.loc[stroke_data["heart_disease"]==1, ["smoking_status"]]

# Find the number of current smokers and patients with heart disease
num_heart_disease = len(heart_disease)
curr_smokers = len(heart_disease[heart_disease["smoking_status"]=="smokes"])

# Calculate the fraction of people with heart disease who smoke
fraction = curr_smokers / num_heart_disease
print(f"There are {num_heart_disease} patients with heart disease, of which {curr_smokers} smoke.")
print(f"The fraction of patients with heart disease who smoke is {fraction}.")
# Out:
# There are 276 patients with heart disease, of which 61 smoke.
# The fraction of patients with heart disease who smoke is 0.2210144927536232.

# %% [markdown]
# One of your medical students passes out in front of you. While initially you believe that they may have been so impressed by your findings, another of your fellow physicians reminds you that they are diabetic and could be hypoglycemic. "He can't be hypoglycemic because he's from the city not some rural area," you tell them.
#
# As the other physician checks the medical student's blood glucose levels and begins giving him oral glucose, you decide to dive back into the data to prove your point.

# %% [markdown]
# ### Exercise 2: Calculate the average glucose level for people living in urban vs. rural areas.

# %%
# Find patients who live in urban and rural areas
stroke_data["Residence_type"].value_counts()
urban = stroke_data.loc[stroke_data["Residence_type"]=="Urban", :]
rural = stroke_data.loc[stroke_data["Residence_type"]=="Rural", :]

# Calculate the average glucose level for each group
print(f"The average glucose level for patients living in an urban setting is {urban['avg_glucose_level'].mean():.2f}")
print(f"The average glucose level for patients living in a rural setting is {rural['avg_glucose_level'].mean():.2f}")
# Out:
# The average glucose level for patients living in an urban setting is 105.93
# The average glucose level for patients living in a rural setting is 106.38

# %% [markdown]
# The medical student shortly awakens as you learn that patients living in urban and rural settings have a similar average glucose level. Humbled by this finding, you realize that perhaps you should use your newfound data science skills in situations when it is appropriate to do so.
